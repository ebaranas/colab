# %% [markdown]
# <a href="https://colab.research.google.com/github/ebaranas/colab/blob/master/election_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import numpy as np
import random
from matplotlib import pyplot as plt

# %%
start = time.time()

ratio = .5
population = 5500
a = int(ratio*population)
b = population - x

voters_a_x = [random.uniform(0,1) for i in range(a)]
voters_a_y = [random.uniform(0,1) for i in range(a)]

voters_b_x = [random.uniform(0,1) for i in range(b)]
voters_b_y = [random.uniform(0,1) for i in range(b)]

plt.scatter(voters_a_x, voters_a_y)
plt.scatter(voters_b_x, voters_b_y)


end = time.time()
print((end - start)*10**6/60)
# Out:
# 2698.0996131896973
